# %% [markdown]
# ## Local Preprocessing Step

# %%
# !zenml stack set local_stack_with_remote_artifact_store

# %%
from pipelines.nb_preprocess import llm_peft_preprocess

llm_peft_preprocess.with_options(
    config_path="configs/phi3_finetune.yaml",
    enable_cache=False,
)()
# Out:
# Initiating a new run for the pipeline: llm_peft_preprocess.
# Configuration for step invocations {'promote', 'finetune'} cannot be applied to any pipeline step invocations, ignoring...
# Reusing registered pipeline version: (version: 1).
# Building Docker image(s) for pipeline llm_peft_preprocess.
# Building Docker image demozenmlcontainerregistry.azurecr.io/zenml:llm_peft_preprocess-orchestrator.
# - Including stack requirements: adlfs>=2021.10.0, azure-identity==1.10.0, azure-keyvault-keys, azure-keyvault-secrets, azure-mgmt-containerservice>=20.0.0, azure-storage-blob==12.17.0, azureml-core==1.54.0.post1, kubernetes, kubernetes>=21.7,<26
# - Including user-defined requirements from file /home/strickvl/coding/zenml-projects/llm-lora-finetuning/requirements.txt
# Including apt packages: git
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# ...

# %%
# !zenml stack set aws_k8s_gpu

# %%
# !zenml stack describe

# %%
from pipelines.nb_train import llm_peft_finetune

llm_peft_finetune.with_options(
    config_path="configs/phi3_finetune.yaml",
    enable_cache=False,
)()
