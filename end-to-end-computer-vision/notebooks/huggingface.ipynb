# %%
import fiftyone as fo

# %%
import fiftyone as fo
import fiftyone.utils.huggingface as fouh

# Load the dataset
# Note: other available arguments include 'max_samples', etc
dataset = fouh.load_from_hub("Voxel51/mvtec-ad", max_samples=5)

# Launch the App
session = fo.launch_app(dataset)
# Out:
# Downloading config file fiftyone.yml from Voxel51/mvtec-ad
# Loading dataset
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 6
#       2 import fiftyone.utils.huggingface as fouh
#       4 # Load the dataset
#       5 # Note: other available arguments include 'max_samples', etc
# ----> 6 dataset = fouh.load_from_hub("Voxel51/mvtec-ad", max_samples=5)
#       8 # Launch the App
#       9 session = fo.launch_app(dataset)
#
# File ~/.pyenv/versions/3.10.12/envs/ls51/lib/python3.10/site-packages/fiftyone/utils/huggingface.py:273, in load_from_hub(repo_id, revision, split, splits, subset, subsets, max_samples, batch_size, num_workers, overwrite, persistent, name, token, config_file, **kwargs)
#     270 if config is None:
#     271     raise ValueError(f"Could not find fiftyone metadata for {repo_id}")
# --> 273 return _load_dataset_from_config(config, **kwargs)
#
# File ~/.pyenv/versions/3.10.12/envs/ls51/lib/python3.10/site-packages/fiftyone/utils/huggingface.py:665, in _load_dataset_from_config(config, **kwargs)
#     663     return _load_parquet_files_dataset_from_config(config, **kwargs)
#     664 else:
# --> 665     return _load_fiftyone_dataset_from_config(config, **kwargs)
#
# File ~/.pyenv/versions/3.10.12/envs/ls51/lib/python3.10/site-packages/fiftyone/utils/huggingface.py:1144, in _load_fiftyone_dataset_from_config(config, **kwargs)
#    1141 if name is not None:
#    1142     dataset_kwargs["name"] = name
# -> 1144 dataset = fod.Dataset.from_dir(download_dir, **dataset_kwargs)
#    1146 if dataset_type_name != "FiftyOneDataset":
#    1147     return dataset
#
# File ~/.pyenv/versions/3.10.12/envs/ls51/lib/python3.10/site-packages/fiftyone/core/dataset.py:5557, in Dataset.from_dir(cls, dataset_dir, dataset_type, data_path, labels_path, name, persistent, overwrite, label_field, tags, dynamic, progress, **kwargs)
#    5445 @classmethod
#    5446 def from_dir(
#    5447     cls,
#    (...)
#    5459     **kwargs,
#    5460 ):
#    5461     """Creates a :class:`Dataset` from the contents of the given directory.
#    5462
#    5463     You can create datasets with this method via the following basic
#    (...)
#    5555         a :class:`Dataset`
#    5556     """
# -> 5557     dataset = cls(name, persistent=persistent, overwrite=overwrite)
#    5558     dataset.add_dir(
#    5559         dataset_dir=dataset_dir,
#    5560         dataset_type=dataset_type,
#    (...)
#    5567         **kwargs,
#    5568     )
#    5569     return dataset
#
# File ~/.pyenv/versions/3.10.12/envs/ls51/lib/python3.10/site-packages/fiftyone/core/singletons.py:36, in DatasetSingleton.__call__(cls, name, _create, *args, **kwargs)
#      29 if (
#      30     _create
#      31     or instance is None
#      32     or instance.deleted
#      33     or instance.name is None
#      34 ):
#      35     instance = cls.__new__(cls)
# ---> 36     instance.__init__(name=name, _create=_create, *args, **kwargs)
#      37     name = instance.name  # `__init__` may have changed `name`
#      38 else:
#
# File ~/.pyenv/versions/3.10.12/envs/ls51/lib/python3.10/site-packages/fiftyone/core/dataset.py:285, in Dataset.__init__(self, name, persistent, overwrite, _create, _virtual, **kwargs)
#     282     delete_dataset(name)
#     284 if _create:
# --> 285     doc, sample_doc_cls, frame_doc_cls = _create_dataset(
#     286         self, name, persistent=persistent, **kwargs
#     287     )
#     288 else:
#     289     doc, sample_doc_cls, frame_doc_cls = _load_dataset(
#     290         self, name, virtual=_virtual
#     291     )
#
# File ~/.pyenv/versions/3.10.12/envs/ls51/lib/python3.10/site-packages/fiftyone/core/dataset.py:6934, in _create_dataset(obj, name, persistent, _patches, _frames, _clips, _src_collection)
#    6925 def _create_dataset(
#    6926     obj,
#    6927     name,
#    (...)
#    6932     _src_collection=None,
#    6933 ):
# -> 6934     slug = _validate_dataset_name(name)
#    6936     _id = ObjectId()
#    6938     sample_collection_name = _make_sample_collection_name(
#    6939         _id, patches=_patches, frames=_frames, clips=_clips
#    6940     )
#
# File ~/.pyenv/versions/3.10.12/envs/ls51/lib/python3.10/site-packages/fiftyone/core/dataset.py:115, in _validate_dataset_name(name, skip)
#     113 clashing_name = clashing_name_doc["name"]
#     114 if clashing_name == name:
# --> 115     raise ValueError(f"Dataset name '{name}' is not available")
#     116 else:
#     117     raise ValueError(
#     118         f"Dataset name '{name}' is not available: slug '{slug}' "
#     119         f"in use by dataset '{clashing_name}'"
#     120     )
#
# ValueError: Dataset name 'Voxel51/mvtec-ad' is not available

# %%
# Suppress Ultralytics logging
import os

os.environ["YOLO_VERBOSE"] = "False"

import fiftyone as fo
from ultralytics import YOLO

# YOLOv8
model = YOLO("yolov8s.pt")

# %%
dataset.apply_model(model, label_field="boxes")

session = fo.launch_app(dataset)
