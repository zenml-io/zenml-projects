# %%
from zenml.client import Client

artifact = Client().get_artifact_version(
    "5d3051f8-22e6-4dca-8949-64043315ae91"
)
loaded_artifact = artifact.load()
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:4                                                                                    │
# │                                                                                                  │
# │   1 from zenml.client import Client                                                              │
# │   2                                                                                              │
# │   3 artifact = Client().get_artifact_version('5d3051f8-22e6-4dca-8949-64043315ae91')             │
# │ ❱ 4 loaded_artifact = artifact.load()                                                            │
# │   5                                                                                              │
# │                                                                                                  │
# │ /home/strickvl/.pyenv/versions/3.10.12/envs/ls51/lib/python3.10/site-packages/zenml/models/v2/co │
# │ re/artifact_version.py:341 in load                                                               │
# │                                                                                                  │
# │   338 │   │   """                                                                                │
# │   339 │   │   from zenml.artifacts.utils import load_artifact_from_response                      │
# │   340 │   │                                                                                      │
# │ ❱ 341 │   │   return load_artifact_from_response(self)                                           │
# │   342 │                                                                                          │
# │   343 │   def download_files(self, path: str, overwrite: bool = False) -> None:                  │
# │   344 │   │   """Downloads data for an artifact with no materializing.                           │
# │                                                                                                  │
# │ /home/strickvl/.pyenv/versions/3.10.12/envs/ls51/lib/python3.10/site-packages/zenml/artifacts/ut │
# │ ils.py:466 in load_artifact_from_response                                                        │
# │                                                                                                  │
# │   463 │   │   artifact=artifact                                                                  │
# │   464 │   )                                                                                      │
# │   465 │                                                                                          │
# │ ❱ 466 │   return _load_artifact_from_uri(                                                        │
# │   467 │   │   materializer=artifact.materializer,                                                │
# │   468 │   │   data_type=artifact.data_type,                                                      │
# │   469 │   │   uri=artifact.uri,                                                                  │
# │                                                                                                  │
# │ /home/strickvl/.pyenv/versions/3.10.12/envs/ls51/lib/python3.10/site-packages/zenml/artifacts/ut │
# │ ils.py:638 in _load_artifact_from_uri                                                            │
# │                                                                                                  │
# │   635 │   materializer_object: BaseMaterializer = materializer_class(                            │
# │   636 │   │   uri, artifact_store                                                                │
# │   637 │   )                                                                                      │
# │ ❱ 638 │   artifact = materializer_object.load(artifact_class)                                    │
# │   639 │   logger.debug("Artifact loaded successfully.")                                          │
# │   640 │                                                                                          │
# │   641 │   return artifact                                                                        │
# │                                                                                                  │
# │ /home/strickvl/coding/zenml-projects/end-to-end-computer-vision/materializers/yolo_materializer. │
# │ py:53 in load                                                                                    │
# │                                                                                                  │
# │   50 │   │                                                                                       │
# │   51 │   │   # Create a temporary folder                                                         │
# │   52 │   │   with tempfile.TemporaryDirectory(prefix="zenml-temp-") as temp_dir:                 │
# │ ❱ 53 │   │   │   temp_file = os.path.join(str(temp_dir), DEFAULT_FILENAME)                       │
# │   54 │   │   │                                                                                   │
# │   55 │   │   │   # Copy from artifact store to temporary file                                    │
# │   56 │   │   │   fileio.copy(filepath, temp_file)                                                │
# │                                                                                                  │
# │ /home/strickvl/.pyenv/versions/3.10.12/envs/ls51/lib/python3.10/site-packages/ultralytics/models │
# │ /yolo/model.py:23 in __init__                                                                    │
# │                                                                                                  │
# │    20 │   │   │   self.__dict__ = new_instance.__dict__                                          │
# │    21 │   │   else:                                                                              │
# │    22 │   │   │   # Continue with default YOLO initialization                                    │
# │ ❱  23 │   │   │   super().__init__(model=model, task=task, verbose=verbose)                      │
# │    24 │                                                                                          │
# │    25 │   @property                                                                              │
# │    26 │   def task_map(self):                                                                    │
# │                                                                                                  │
# │ /home/strickvl/.pyenv/versions/3.10.12/envs/ls51/lib/python3.10/site-packages/ultralytics/engine │
# │ /model.py:151 in __init__                                                                        │
# │                                                                                                  │
# │   148 │   │   if Path(model).suffix in {".yaml", ".yml"}:                                        │
# │   149 │   │   │   self._new(model, task=task, verbose=verbose)                                   │
# │   150 │   │   else:                                                                              │
# │ ❱ 151 │   │   │   self._load(model, task=task)                                                   │
# │   152 │                                                                                          │
# │   153 │   def __call__(                                                                          │
# │   154 │   │   self,                                                                              │
# │                                                                                                  │
# │ /home/strickvl/.pyenv/versions/3.10.12/envs/ls51/lib/python3.10/site-packages/ultralytics/engine │
# │ /model.py:240 in _load                                                                           │
# │                                                                                                  │
# │   237 │   │   weights = checks.check_model_file_from_stem(weights)  # add suffix, i.e. yolov8n   │
# │   238 │   │                                                                                      │
# │   239 │   │   if Path(weights).suffix == ".pt":                                                  │
# │ ❱ 240 │   │   │   self.model, self.ckpt = attempt_load_one_weight(weights)                       │
# │   241 │   │   │   self.task = self.model.args["task"]                                            │
# │   242 │   │   │   self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)      │
# │   243 │   │   │   self.ckpt_path = self.model.pt_path                                            │
# │                                                                                                  │
# │ /home/strickvl/.pyenv/versions/3.10.12/envs/ls51/lib/python3.10/site-packages/ultralytics/nn/tas │
# │ ks.py:806 in attempt_load_one_weight                                                             │
# │                                                                                                  │
# │    803                                                                                           │
# │    804 def attempt_load_one_weight(weight, device=None, inplace=True, fuse=False):               │
# │    805 │   """Loads a single model weights."""                                                   │
# │ ❱  806 │   ckpt, weight = torch_safe_load(weight)  # load ckpt                                   │
# │    807 │   args = {**DEFAULT_CFG_DICT, **(ckpt.get("train_args", {}))}  # combine model and def  │
# │    808 │   model = (ckpt.get("ema") or ckpt["model"]).to(device).float()  # FP32 model           │
# │    809                                                                                           │
# │                                                                                                  │
# │ /home/strickvl/.pyenv/versions/3.10.12/envs/ls51/lib/python3.10/site-packages/ultralytics/nn/tas │
# │ ks.py:732 in torch_safe_load                                                                     │
# │                                                                                                  │
# │    729 │   │   │   │   "ultralytics.yolo.data": "ultralytics.data",                              │
# │    730 │   │   │   }                                                                             │
# │    731 │   │   ):  # for legacy 8.0 Classify and Pose models                                     │
# │ ❱  732 │   │   │   ckpt = torch.load(file, map_location="cpu")                                   │
# │    733 │                                                                                         │
# │    734 │   except ModuleNotFoundError as e:  # e.name is missing module name                     │
# │    735 │   │   if e.name == "models":                                                            │
# │                                                                                                  │
# │ /home/strickvl/.pyenv/versions/3.10.12/envs/ls51/lib/python3.10/site-packages/torch/serializatio │
# │ n.py:1040 in load                                                                                │
# │                                                                                                  │
# │   1037 │   │   │   │   return _legacy_load(opened_file, map_location, _weights_only_unpickler,   │
# │   1038 │   │   │   except RuntimeError as e:                                                     │
# │   1039 │   │   │   │   raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None           │
# │ ❱ 1040 │   │   return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args  │
# │   1041                                                                                           │
# │   1042                                                                                           │
# │   1043 # Register pickling support for layout instances such as                                  │
# │                                                                                                  │
# │ /home/strickvl/.pyenv/versions/3.10.12/envs/ls51/lib/python3.10/site-packages/torch/serializatio │
# │ n.py:1258 in _legacy_load                                                                        │
# │                                                                                                  │
# │   1255 │   │   │   f"Received object of type \"{type(f)}\". Please update to Python 3.8.2 or ne  │
# │   1256 │   │   │   "functionality.")                                                             │
# │   1257 │                                                                                         │
# │ ❱ 1258 │   magic_number = pickle_module.load(f, **pickle_load_args)                              │
# │   1259 │   if magic_number != MAGIC_NUMBER:                                                      │
# │   1260 │   │   raise RuntimeError("Invalid magic number; corrupt file?")                         │
# │   1261 │   protocol_version = pickle_module.load(f, **pickle_load_args)                          │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# UnpicklingError: invalid load key, '\x08'.

# %%
from ultralytics import YOLO

model_path = yolo_model.model_name
ship_model = YOLO(model_path, names=["ship"])
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:4                                                                                    │
# │                                                                                                  │
# │   1 from ultralytics import YOLO                                                                 │
# │   2                                                                                              │
# │   3 model_path = yolo_model.model_name                                                           │
# │ ❱ 4 ship_model = YOLO(model_path, names=['ship'])                                                │
# │   5                                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# TypeError: YOLO.__init__() got an unexpected keyword argument 'names'

# %%
from rich import inspect

inspect(yolo_model, methods=True)

# %%
yolo_model.names = ["ship"]
# Predict with the model
results = yolo_model(
    "https://ultralytics.com/images/bus.jpg"
)  # predict on an image
print(results)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 yolo_model.names = ['ship']                                                                  │
# │   2 # Predict with the model                                                                     │
# │   3 results = yolo_model('https://ultralytics.com/images/bus.jpg')  # predict on an image        │
# │   4 print(results)                                                                               │
# │                                                                                                  │
# │ /home/strickvl/.pyenv/versions/3.10.12/envs/ls51/lib/python3.10/site-packages/torch/nn/modules/m │
# │ odule.py:1747 in __setattr__                                                                     │
# │                                                                                                  │
# │   1744 │   │   │   │   │   │   │   value = output                                                │
# │   1745 │   │   │   │   │   buffers[name] = value                                                 │
# │   1746 │   │   │   │   else:                                                                     │
# │ ❱ 1747 │   │   │   │   │   super().__setattr__(name, value)                                      │
# │   1748 │                                                                                         │
# │   1749 │   def __delattr__(self, name):                                                          │
# │   1750 │   │   if name in self._parameters:                                                      │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# AttributeError: can't set attribute 'names'

# %%
from PIL import Image

res = results[0].plot()[:, :, [2, 1, 0]]
Image.fromarray(res)
# Out:
# <PIL.Image.Image image mode=RGB size=810x1080>

# %%
results[0].names
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}
